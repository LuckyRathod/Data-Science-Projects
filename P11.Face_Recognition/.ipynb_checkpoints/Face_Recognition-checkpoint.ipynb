# %%
# !unzip "Datasets.zip"
# Out:
# Archive:  Datasets.zip
#    creating: Datasets/
#    creating: Datasets/Test/
#    creating: Datasets/Test/Lucky/
#   inflating: Datasets/Test/Lucky/100.jpg
#   inflating: Datasets/Test/Lucky/97.jpg
#   inflating: Datasets/Test/Lucky/98.jpg
#   inflating: Datasets/Test/Lucky/99.jpg
#    creating: Datasets/Test/Mom/
#   inflating: Datasets/Test/Mom/100.jpg
#   inflating: Datasets/Test/Mom/97.jpg
#   inflating: Datasets/Test/Mom/98.jpg
#   inflating: Datasets/Test/Mom/99.jpg
#    creating: Datasets/Train/
#    creating: Datasets/Train/Lucky/
#   inflating: Datasets/Train/Lucky/1.jpg
#   inflating: Datasets/Train/Lucky/10.jpg
#   inflating: Datasets/Train/Lucky/11.jpg
#   inflating: Datasets/Train/Lucky/12.jpg
#   inflating: Datasets/Train/Lucky/13.jpg
#   inflating: Datasets/Train/Lucky/14.jpg
#   inflating: Datasets/Train/Lucky/15.jpg
#   inflating: Datasets/Train/Lucky/16.jpg
#   inflating: Datasets/Train/Lucky/17.jpg
#   inflating: Datasets/Train/Lucky/18.jpg
#   inflating: Datasets/Train/Lucky/19.jpg
#   inflating: Datasets/Train/Lucky/2.jpg
#   inflating: Datasets/Train/Lucky/20.jpg
#   inflating: Datasets/Train/Lucky/21.jpg
#   inflating: Datasets/Train/Lucky/22.jpg
#   inflating: Datasets/Train/Lucky/23.jpg
#   inflating: Datasets/Train/Lucky/24.jpg
#   inflating: Datasets/Train/Lucky/25.jpg
#   inflating: Datasets/Train/Lucky/26.jpg
#   inflating: Datasets/Train/Lucky/27.jpg
#   inflating: Datasets/Train/Lucky/28.jpg
#   inflating: Datasets/Train/Lucky/29.jpg
#   inflating: Datasets/Train/Lucky/3.jpg
#   inflating: Datasets/Train/Lucky/30.jpg
#   inflating: Datasets/Train/Lucky/31.jpg
#   inflating: Datasets/Train/Lucky/32.jpg
#   inflating: Datasets/Train/Lucky/33.jpg
#   inflating: Datasets/Train/Lucky/34.jpg
#   inflating: Datasets/Train/Lucky/35.jpg
#   inflating: Datasets/Train/Lucky/36.jpg
#   inflating: Datasets/Train/Lucky/37.jpg
#   inflating: Datasets/Train/Lucky/38.jpg
#   inflating: Datasets/Train/Lucky/39.jpg
#   inflating: Datasets/Train/Lucky/4.jpg
#   inflating: Datasets/Train/Lucky/40.jpg
#   inflating: Datasets/Train/Lucky/41.jpg
#   inflating: Datasets/Train/Lucky/42.jpg
#   inflating: Datasets/Train/Lucky/43.jpg
#   inflating: Datasets/Train/Lucky/44.jpg
#   inflating: Datasets/Train/Lucky/45.jpg
#   inflating: Datasets/Train/Lucky/46.jpg
#   inflating: Datasets/Train/Lucky/47.jpg
#   inflating: Datasets/Train/Lucky/48.jpg
#   inflating: Datasets/Train/Lucky/49.jpg
#   inflating: Datasets/Train/Lucky/5.jpg
#   inflating: Datasets/Train/Lucky/50.jpg
#   inflating: Datasets/Train/Lucky/51.jpg
#   inflating: Datasets/Train/Lucky/52.jpg
#   inflating: Datasets/Train/Lucky/53.jpg
#   inflating: Datasets/Train/Lucky/54.jpg
#   inflating: Datasets/Train/Lucky/55.jpg
#   inflating: Datasets/Train/Lucky/56.jpg
#   inflating: Datasets/Train/Lucky/57.jpg
#   inflating: Datasets/Train/Lucky/58.jpg
#   inflating: Datasets/Train/Lucky/59.jpg
#   inflating: Datasets/Train/Lucky/6.jpg
#   inflating: Datasets/Train/Lucky/60.jpg
#   inflating: Datasets/Train/Lucky/61.jpg
#   inflating: Datasets/Train/Lucky/62.jpg
#   inflating: Datasets/Train/Lucky/63.jpg
#   inflating: Datasets/Train/Lucky/64.jpg
#   inflating: Datasets/Train/Lucky/65.jpg
#   inflating: Datasets/Train/Lucky/66.jpg
#   inflating: Datasets/Train/Lucky/67.jpg
#   inflating: Datasets/Train/Lucky/68.jpg
#   inflating: Datasets/Train/Lucky/69.jpg
#   inflating: Datasets/Train/Lucky/7.jpg
#   inflating: Datasets/Train/Lucky/70.jpg
#   inflating: Datasets/Train/Lucky/71.jpg
#   inflating: Datasets/Train/Lucky/72.jpg
#   inflating: Datasets/Train/Lucky/73.jpg
#   inflating: Datasets/Train/Lucky/74.jpg
#   inflating: Datasets/Train/Lucky/75.jpg
#   inflating: Datasets/Train/Lucky/76.jpg
#   inflating: Datasets/Train/Lucky/77.jpg
#   inflating: Datasets/Train/Lucky/78.jpg
#   inflating: Datasets/Train/Lucky/79.jpg
#   inflating: Datasets/Train/Lucky/8.jpg
#   inflating: Datasets/Train/Lucky/80.jpg
#   inflating: Datasets/Train/Lucky/81.jpg
#   inflating: Datasets/Train/Lucky/82.jpg
#   inflating: Datasets/Train/Lucky/83.jpg
#   inflating: Datasets/Train/Lucky/84.jpg
#   inflating: Datasets/Train/Lucky/85.jpg
#   inflating: Datasets/Train/Lucky/86.jpg
#   inflating: Datasets/Train/Lucky/87.jpg
#   inflating: Datasets/Train/Lucky/88.jpg
#   inflating: Datasets/Train/Lucky/89.jpg
#   inflating: Datasets/Train/Lucky/9.jpg
#   inflating: Datasets/Train/Lucky/90.jpg
#   inflating: Datasets/Train/Lucky/91.jpg
#   inflating: Datasets/Train/Lucky/92.jpg
#   inflating: Datasets/Train/Lucky/93.jpg
#   inflating: Datasets/Train/Lucky/94.jpg
#   inflating: Datasets/Train/Lucky/95.jpg
#   inflating: Datasets/Train/Lucky/96.jpg
#    creating: Datasets/Train/Mom/
#   inflating: Datasets/Train/Mom/1.jpg
#   inflating: Datasets/Train/Mom/10.jpg
#   inflating: Datasets/Train/Mom/11.jpg
#   inflating: Datasets/Train/Mom/12.jpg
#   inflating: Datasets/Train/Mom/13.jpg
#   inflating: Datasets/Train/Mom/14.jpg
#   inflating: Datasets/Train/Mom/15.jpg
#   inflating: Datasets/Train/Mom/16.jpg
#   inflating: Datasets/Train/Mom/17.jpg
#   inflating: Datasets/Train/Mom/18.jpg
#   inflating: Datasets/Train/Mom/19.jpg
#   inflating: Datasets/Train/Mom/2.jpg
#   inflating: Datasets/Train/Mom/20.jpg
#   inflating: Datasets/Train/Mom/21.jpg
#   inflating: Datasets/Train/Mom/22.jpg
#   inflating: Datasets/Train/Mom/82.jpg
#   inflating: Datasets/Train/Mom/83.jpg
#   inflating: Datasets/Train/Mom/84.jpg
#   inflating: Datasets/Train/Mom/85.jpg
#   inflating: Datasets/Train/Mom/86.jpg
#   inflating: Datasets/Train/Mom/87.jpg
#   inflating: Datasets/Train/Mom/88.jpg
#   inflating: Datasets/Train/Mom/89.jpg
#   inflating: Datasets/Train/Mom/9.jpg
#   inflating: Datasets/Train/Mom/90.jpg
#   inflating: Datasets/Train/Mom/91.jpg
#   inflating: Datasets/Train/Mom/92.jpg
#   inflating: Datasets/Train/Mom/93.jpg
#   inflating: Datasets/Train/Mom/94.jpg
#   inflating: Datasets/Train/Mom/95.jpg
#   inflating: Datasets/Train/Mom/96.jpg

# %%
# -*- coding: utf-8 -*-


from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# re-size all the images to this
IMAGE_SIZE = [224, 224]

train_path = 'Datasets/Train'
valid_path = 'Datasets/Test'

# add preprocessing layer to the front of VGG
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# don't train existing weights
for layer in vgg.layers:
  layer.trainable = False
  

  
  # useful for getting number of classes
folders = glob('Datasets/Train/*')
  

# our layers - you can add more if you want
x = Flatten()(vgg.output)
# x = Dense(1000, activation='relu')(x)
prediction = Dense(len(folders), activation='softmax')(x)

# create a model object
model = Model(inputs=vgg.input, outputs=prediction)

# view the structure of the model
model.summary()

# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)


from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('Datasets/Train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory('Datasets/Test',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')

'''r=model.fit_generator(training_set,
                         samples_per_epoch = 8000,
                         nb_epoch = 5,
                         validation_data = test_set,
                         nb_val_samples = 2000)'''

# fit the model
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=10,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# accuracies
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
plt.savefig('AccVal_acc')

import tensorflow as tf

from tensorflow.keras.models import load_model

model.save('facefeatures_new_model.h5')
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 50178
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
# Found 192 images belonging to 2 classes.
# Found 8 images belonging to 2 classes.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 6/6 [==============================] - 4s 596ms/step - loss: 1.3538 - accuracy: 0.5052 - val_loss: 1.0497 - val_accuracy: 0.5000
# Epoch 2/10
# 6/6 [==============================] - 3s 546ms/step - loss: 0.2847 - accuracy: 0.8594 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 3/10
# 6/6 [==============================] - 3s 541ms/step - loss: 0.1312 - accuracy: 0.9479 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 4/10
# 6/6 [==============================] - 3s 537ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.1205e-04 - val_accuracy: 1.0000
# Epoch 5/10
# 6/6 [==============================] - 3s 542ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 2.1756e-04 - val_accuracy: 1.0000
# Epoch 6/10
# 6/6 [==============================] - 3s 543ms/step - loss: 0.0155 - accuracy: 0.9948 - val_loss: 1.4946e-04 - val_accuracy: 1.0000
# Epoch 7/10
# 6/6 [==============================] - 3s 538ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 5.6218e-05 - val_accuracy: 1.0000
# Epoch 8/10
# 6/6 [==============================] - 3s 537ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 2.4899e-05 - val_accuracy: 1.0000
# Epoch 9/10
# 6/6 [==============================] - 3s 534ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.9222e-05 - val_accuracy: 1.0000
# Epoch 10/10
# 6/6 [==============================] - 3s 540ms/step - loss: 6.6620e-04 - accuracy: 1.0000 - val_loss: 2.0429e-05 - val_accuracy: 1.0000

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.19.5)
